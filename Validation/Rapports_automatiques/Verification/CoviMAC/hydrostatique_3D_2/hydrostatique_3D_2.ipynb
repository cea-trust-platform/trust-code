# %% [markdown]
# # Verification hydrostatique

# %%
from trustutils import run

run.introduction('Y.G')
run.description("")
run.TRUST_parameters()
# Out:
# ## Introduction
#  Validation made by : Y.G
#  Report generated 26/01/2022
# ### Description
# ### TRUST parameters
#  * Version TRUST: 1.8.4
#  * Binary used: /volatile/catA/ll258196/trust-code/exec/TRUST_mpi_opt (built on TRUST /volatile/catA/ll258196/trust-code/Validation/Rapports_automatiques/Verification/CoviMAC/hydrostatique_3D_2/build)

# %% [markdown]
# ### Test cases
#
# * /gauche.data :
# * /droite.data :
# * /haut.data :
# * /bas.data :
# * /devant.data :
# * /derriere.data :

# %%
from trustutils import run 
c1 = run.addCase("."    ,"gauche.data") 
c2 = run.addCase("."    ,"droite.data") 
c3 = run.addCase("."    ,"haut.data") 
c4 = run.addCase("."    ,"bas.data") 
c5 = run.addCase("."    ,"devant.data") 
c6 = run.addCase("."    ,"derriere.data")
run.printCases()
run.runCases()
# Out:
# ### Test cases
# * ./gauche.data :
# * ./droite.data :
# * ./haut.data :
# * ./bas.data :
# * ./devant.data :
# * ./derriere.data :
# Running **with Sserver**...
#   => A total of 6 cases were (successfully) run in 0.4s.

# %% [markdown]
# ## CoviMAC
# Test du gradient de pression en non conforme

# %% [markdown]
# ### Mesh : CoviMAC
# A remplir

# %%
from trustutils import visit

visit.showField("./droite.lata","Pseudocolor","PRESSION_ELEM_dom")

# %% [markdown]
# ### Comparaison theorie/numerique

# %%
from trustutils.jupyter import plot
import numpy as np

Tableau=plot.Table(["$\| P \|_{\infty}$","$\| \overrightarrow{v} \|_{\infty}$"])
data=plot.loadText("droite_erreurs.txt")
Tableau.addLigne([data],"droite")
data=plot.loadText("gauche_erreurs.txt")
Tableau.addLigne([data],"gauche")
data=plot.loadText("devant_erreurs.txt")
Tableau.addLigne([data],"devant")
data=plot.loadText("derriere_erreurs.txt")
Tableau.addLigne([data],"derriere")
data=plot.loadText("haut_erreurs.txt")
Tableau.addLigne([data],"haut")
data=plot.loadText("bas_erreurs.txt")
Tableau.addLigne([data],"bas")
Tableau.df
# Out:
#           $\| P \|_{\infty}$  $\| \overrightarrow{v} \|_{\infty}$
# droite          1.455192e-11                         1.343189e-11
# gauche          1.455192e-11                         1.227644e-11
# devant          2.182787e-11                         2.581433e-11
# derriere        2.182787e-11                         2.070640e-11
# haut            1.455192e-11                         1.603061e-11
# bas             2.182787e-11                         1.202216e-11

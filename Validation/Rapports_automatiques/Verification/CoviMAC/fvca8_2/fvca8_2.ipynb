# %% [markdown]
# # Benchmark FVCA8

# %%
from trustutils import run 

run.introduction("A. Gerschenfeld, Y. Gorsse")
run.description("Cas tests de Stokes 2D sur les maillages FVCA8, et Navier-Stokes 3D sur maillages FVCA8-3D et FVCA6-3D.")
run.TRUST_parameters()
# Out:
# ## Introduction
#  Validation made by : A. Gerschenfeld, Y. Gorsse
#  Report generated 25/01/2022
# ### Description
# Cas tests de Stokes 2D sur les maillages FVCA8, et Navier-Stokes 3D sur maillages FVCA8-3D et FVCA6-3D.
# ### TRUST parameters
#  * Version TRUST: 1.8.4
#  * Binary used: /volatile/catA/ll258196/trust-code/exec/TRUST_mpi_opt (built on TRUST /volatile/catA/ll258196/trust-code/Validation/Rapports_automatiques/jupyter/CoviMAC/fvca8_2/build)

# %%
from trustutils import run 
run.reset()
c1 = run.addCase("Triangles/jdd_1"     ,"cas.data",nbProcs=1) 
c2 = run.addCase("Triangles/jdd_2"     ,"cas.data",nbProcs=1)
c3 = run.addCase("Triangles/jdd_3"     ,"cas.data",nbProcs=1) 
c4 = run.addCase("Triangles/jdd_4"     ,"cas.data",nbProcs=1) 
c5 = run.addCase("Triangles/jdd_5"     ,"cas.data",nbProcs=1)

c6 = run.addCase("Quadrangles/jdd_1"   ,"cas.data",nbProcs=1) 
c7 = run.addCase("Quadrangles/jdd_2"   ,"cas.data",nbProcs=1) 
c8 = run.addCase("Quadrangles/jdd_3"   ,"cas.data",nbProcs=1) 
c9 = run.addCase("Quadrangles/jdd_4"   ,"cas.data",nbProcs=1) 
c10 = run.addCase("Quadrangles/jdd_5"   ,"cas.data",nbProcs=1) 
c11 = run.addCase("Quadrangles/jdd_6"   ,"cas.data",nbProcs=1) 

c12 = run.addCase("Cartesian/jdd_1"     ,"cas.data",nbProcs=1) 
c13 = run.addCase("Cartesian/jdd_2"     ,"cas.data",nbProcs=1)
c14 = run.addCase("Cartesian/jdd_3"     ,"cas.data",nbProcs=1)
c15 = run.addCase("Cartesian/jdd_4"     ,"cas.data",nbProcs=1)
c16 = run.addCase("Cartesian/jdd_5"     ,"cas.data",nbProcs=1)
c17 = run.addCase("Cartesian/jdd_6"     ,"cas.data",nbProcs=1)
c18 = run.addCase("Cartesian/jdd_7"     ,"cas.data",nbProcs=1)


c19 = run.addCase("Locally_Refined/jdd_1","cas.data",nbProcs=1) 
c20 = run.addCase("Locally_Refined/jdd_2","cas.data",nbProcs=1)
c21 = run.addCase("Locally_Refined/jdd_3","cas.data",nbProcs=1)
c22 = run.addCase("Locally_Refined/jdd_4","cas.data",nbProcs=1)
c23 = run.addCase("Locally_Refined/jdd_5","cas.data",nbProcs=1)
c24 = run.addCase("Locally_Refined/jdd_6","cas.data",nbProcs=1)


c25 = run.addCase("Voronoi/jdd_1"       ,"cas.data",nbProcs=1) 
c26 = run.addCase("Prism/jdd_1"         ,"cas.data",nbProcs=1) 
c27 = run.addCase("Hexa/jdd_1"          ,"cas.data",nbProcs=1) 
c28= run.addCase("Tetra/jdd_1"         ,"cas.data",nbProcs=1) 
c29= run.addCase("PrismHexa/jdd_1"     ,"cas.data",nbProcs=1) 
c30= run.addCase("Kershaw/jdd_1"       ,"cas.data",nbProcs=1) 
c31= run.addCase("LocRaf/jdd_1"        ,"cas.data",nbProcs=1) 
c32= run.addCase("Random/jdd_1"        ,"cas.data",nbProcs=1) 
c33= run.addCase("CheckerBoard/jdd_1"  ,"cas.data",nbProcs=1)

run.printCases()
run.runCases()
# Out:
# ### Test cases
# * Triangles/jdd_1/cas.data :
# * Triangles/jdd_2/cas.data :
# * Triangles/jdd_3/cas.data :
# * Triangles/jdd_4/cas.data :
# * Triangles/jdd_5/cas.data :
# * Quadrangles/jdd_1/cas.data :
# * Quadrangles/jdd_2/cas.data :
# * Quadrangles/jdd_3/cas.data :
# * Quadrangles/jdd_4/cas.data :
# * Quadrangles/jdd_5/cas.data :
# * Quadrangles/jdd_6/cas.data :
# * Cartesian/jdd_1/cas.data :
# * Cartesian/jdd_2/cas.data :
# * Cartesian/jdd_3/cas.data :
# * Cartesian/jdd_4/cas.data :
# * Cartesian/jdd_5/cas.data :
# * Cartesian/jdd_6/cas.data :
# * Cartesian/jdd_7/cas.data :
# * Locally_Refined/jdd_1/cas.data :
# * Locally_Refined/jdd_2/cas.data :
# * Locally_Refined/jdd_3/cas.data :
# * Locally_Refined/jdd_4/cas.data :
# * Locally_Refined/jdd_5/cas.data :
# * Locally_Refined/jdd_6/cas.data :
# * Voronoi/jdd_1/cas.data :
# * Prism/jdd_1/cas.data :
# * Hexa/jdd_1/cas.data :
# * Tetra/jdd_1/cas.data :
# * PrismHexa/jdd_1/cas.data :
# * Kershaw/jdd_1/cas.data :
# ...

# %% [markdown]
# ## Stokes stationnaire 2D: Bercovier-Engelman.

# %%
from trustutils import visit
plot=visit.Show("Triangles/jdd_1/cas.lata",field="Mesh",name="dom",nX=2,nY=2) 
plot.add("Quadrangles/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=0,yIndice=1) 
plot.add("Cartesian/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=1,yIndice=0) 
plot.add("Locally_Refined/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=1,yIndice=1) 
plot.plot()

# %% [markdown]
# ### Ordres de convergence vitesse

# %%
run.executeScript("extract_convergence")

# %% [markdown]
# ### Ordres de convergence pression

# %%
from trustutils.jupyter import plot
import numpy as np

a=plot.Graph("Ordres de convergence pression")

data=plot.loadText("Triangles/conv_glob_p")
a.add(1/np.sqrt(data[0]),data[1],label="Triangles",marker='-|')

data=plot.loadText("Quadrangles/conv_glob_p")
a.add(1/np.sqrt(data[0]),data[1],label="Quadrangles",marker='-x')

data=plot.loadText("Cartesian/conv_glob_p")
a.add(1/np.sqrt(data[0]),data[1],label="Cartesian",marker='-*')

data=plot.loadText("Locally_Refined/conv_glob_p")
a.add(1/np.sqrt(data[0]),data[1],label="Locally_Refined",marker='-s',markerfacecolor='None')

x=np.linspace(0.001,0.2,10)
y=x
a.add(x,y,label="Order 1")

y=x*x
a.add(x,y,label="Order 2")

a.label("N","erreur_max")
a.scale(xscale='log',yscale='log')

# %% [markdown]
# ## Navier-Stokes stationnaire 3D

# %%
from trustutils import visit
plot=visit.Show("Voronoi/jdd_1/cas.lata",field="Mesh",name="dom",nX=3,nY=3)
plot.add("Prism/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=0,yIndice=1) 
plot.add("Hexa/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=0,yIndice=2)
plot.add("Tetra/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=1,yIndice=0)   
plot.add("PrismHexa/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=1,yIndice=1) 
plot.add("Kershaw/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=1,yIndice=2)
plot.add("LocRaf/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=2,yIndice=0)   
plot.add("Random/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=2,yIndice=1) 
plot.add("CheckerBoard/jdd_1/cas.lata",field="Mesh",name="dom",xIndice=2,yIndice=2)
plot.plot()

# %% [markdown]
# ### Ordres de convergence vitesse

# %%
from trustutils.jupyter import plot
import numpy as np

a=plot.Graph("Ordres de convergence vitesse")

data=plot.loadText("Voronoi/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="Voronoi",marker='-|')

data=plot.loadText("Prism/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="Prism",marker='-x')

data=plot.loadText("Hexa/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="Hexa",marker='-*')

data=plot.loadText("Tetra/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="Tetra",marker='-s',markerfacecolor='None')

data=plot.loadText("PrismHexa/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="PrismHexa",marker='-s',markerfacecolor='None')

data=plot.loadText("Kershaw/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="Kershaw",marker='-s',markerfacecolor='None')

data=plot.loadText("LocRaf/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="LocRaf",marker='-s',markerfacecolor='None')

data=plot.loadText("Random/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="Random",marker='-s',markerfacecolor='None')

data=plot.loadText("CheckerBoard/conv_glob_v")
a.add(1/data[0]**(1./3),data[1],label="CheckerBoard",marker='-s',markerfacecolor='None')

x=np.linspace(0.05330018,0.3,10)
y=x
a.add(x,y,label="Order 1")

y=x*x
a.add(x,y,label="Order 2")

a.label("N","erreur_max")
a.scale(xscale='log',yscale='log')

# %% [markdown]
# ### Ordres de convergence pression

# %%
from trustutils.jupyter import plot
import numpy as np

a=plot.Graph("Ordres de convergence pression")

data=plot.loadText("Voronoi/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="Voronoi",marker='-|')

data=plot.loadText("Prism/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="Prism",marker='-x')

data=plot.loadText("Hexa/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="Hexa",marker='-*')

data=plot.loadText("Tetra/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="Tetra",marker='-s',markerfacecolor='None')

data=plot.loadText("PrismHexa/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="PrismHexa",marker='-s',markerfacecolor='None')

data=plot.loadText("Kershaw/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="Kershaw",marker='-s',markerfacecolor='None')

data=plot.loadText("LocRaf/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="LocRaf",marker='-s',markerfacecolor='None')

data=plot.loadText("Random/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="Random",marker='-s',markerfacecolor='None')

data=plot.loadText("CheckerBoard/conv_glob_p")
a.add(1/data[0]**(1./3),data[1],label="CheckerBoard",marker='-s',markerfacecolor='None')

x=np.linspace(0.05330018,0.8,10)
y=x
a.add(x,y,label="Order 1")

y=x*x
a.add(x,y,label="Order 2")

a.label("N","erreur_max")
a.scale(xscale='log',yscale='log')

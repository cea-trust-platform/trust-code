# %% [markdown]
# # Vérification du transposé du gradient de vitesse dans le tenseur des contraintes visqueuses en 3D

# %%
from trustutils import run 

run.introduction("D. Jamet")
run.description("On impose un champ de vitesse à divergence nulle particulier dans tout le domaine. On choisit une viscosité variable en espace. Pour ces deux champs, il est possible de déterminer la solution analytique de la force visqueuse. On impose alors un terme source égal à l'opposé de cette force. Le champ de pression doit ainsi être nul")
run.TRUST_parameters()
# Out:
# ## Introduction
#  Validation made by : D. Jamet
#  Report generated 25/01/2022
# ### Description
# On impose un champ de vitesse à divergence nulle particulier dans tout le domaine. On choisit une viscosité variable en espace. Pour ces deux champs, il est possible de déterminer la solution analytique de la force visqueuse. On impose alors un terme source égal à l'opposé de cette force. Le champ de pression doit ainsi être nul
# ### TRUST parameters
#  * Version TRUST: 1.8.4
#  * Binary used: /volatile/catA/ll258196/trust-code/exec/TRUST_mpi_opt (built on TRUST /volatile/catA/ll258196/trust-code/Validation/Rapports_automatiques/jupyter/EF/EF_Grad_U_Transpose_3D_2D/build)

# %%
from trustutils import run 
import os
c1 = run.addCase(".","grad_u_transpose_3d_2d.data")
run.printCases()
run.runCases()
# Out:
# ### Test cases
# * ./grad_u_transpose_3d_2d.data :
# Running **with Sserver**...
#   => A total of 1 cases were (successfully) run in 0.5s.

# %% [markdown]
# ## Champ de pression
# On vérifie que le champ de pression calculé est bien nul.
# ### Champs de pression calculé
# Le champ de pression 3D calculé par GENEPI est tracé.  Ce champ doit être nul.

# %%
from trustutils import visit

Graphique=visit.Show("./grad_u_transpose_3d_2d.lata","Pseudocolor","PRESSION_PA_ELEM_dom")
Graphique.plot()

# %% [markdown]
# ## Data Files
# ### grad_u_transpose_2d_source

# %%
from trustutils import run

run.dumpDataset("./grad_u_transpose_3d_2d.data")
# Out:
#  # Hydraulique 3D pour tester le grad(u)^T du tenseur visqueux #
#
#  dimension 3
#
#  Pb_hydraulique pb
#
#  Domaine dom
#
#  Mailler dom
#  {
#          Pave Cavite
#          {
#                  Origine -1. -1. -1.
#                  Nombre_de_noeuds 31 31 31
#                  Longueurs 2. 2. 2.
#          }
#          {
#                  Bord Gauche   Y = -1.  -1. <= X <= 1.  -1. <= Z <= 1.
#                  Bord Droit    Y =  1.  -1. <= X <= 1.  -1. <= Z <= 1.
#                  Bord Bas      Z = -1.  -1. <= X <= 1.  -1. <= Y <= 1.
#                  Bord Haut     Z =  1.  -1. <= X <= 1.  -1. <= Y <= 1.
#                  Bord Derriere X = -1.  -1. <= Y <= 1.  -1. <= Z <= 1.
#                  Bord Devant   X =  1.  -1. <= Y <= 1.  -1. <= Z <= 1.
#          }
#  }
#
#  EF dis
#
#  Scheme_euler_explicit sch
#  Read sch
#  {
#  	 tinit 0
#  	 tmax 2.5
#  	 dt_min 1.e-7
#  	 dt_max 5.e-3
#  	 dt_impr 5.e-1
#  	 dt_sauv 1
#  	 seuil_statio 1.e-8
#  	 seuil_statio 1.305e-05
#  }
#
#  Fluide_Incompressible eau
#  Read eau
#  {
#  	 mu Champ_Fonc_XYZ dom 1 (y+z)
#  	 rho Champ_Uniforme 1 2.
#  }
#
#  Associate pb dom
#  Associate pb sch
#  Associate pb eau
#
#  Discretize pb dis
#
#  Read pb
#  {
#  	 Navier_Stokes_standard
#  	 {
#                  methode_calcul_pression_initiale avec_sources_et_operateurs
#  	 	 solveur_pression GCP {
#  	 	 	 precond ssor { omega 1.5 }
#  	 	 	 seuil 1.e-8
#  	 	 }
#  	 	 convection { negligeable }
#  	 	 diffusion {  }
#  	 	 sources { source_qdm Champ_Fonc_XYZ dom 3 (0.) (-1.) (1.) }
#  	 	 initial_conditions {
#  	 	 	 vitesse Champ_Fonc_XYZ dom 3 0. y -z
#  	 	 	 }
#  	 	 boundary_conditions {
#  	 	 	 Gauche frontiere_ouverte_vitesse_imposee
#  	 	 	      Champ_front_fonc_tXYZ 3 0. y -z
#  	 	 	 Droit frontiere_ouverte_vitesse_imposee
#  	 	 	      Champ_front_fonc_tXYZ 3 0. y -z
#  	 	 	 Bas frontiere_ouverte_vitesse_imposee
#  	 	 	      Champ_front_fonc_tXYZ 3 0. y -z
#  	 	 	 Haut frontiere_ouverte_vitesse_imposee
#  	 	 	      Champ_front_fonc_tXYZ 3 0. y -z
#  	 	 	 Derriere frontiere_ouverte_vitesse_imposee
#  	 	 	      Champ_front_fonc_tXYZ 3 0. y -z
#  	 	 	 Devant frontiere_ouverte_vitesse_imposee
#  	 	 	      Champ_front_fonc_tXYZ 3 0. y -z
#  	 	 }
#  	 }
#
#  	 Post_processing
#  	 {
#  	 	 format lata
#  	 	 fields dt_post 5e-1
#  	 	 {
#  	 	 	 pression_pa elem
#  	 	 	 vitesse som
#  	 	 }
#  	 }
#  }
#
#  Solve pb
#
#  End

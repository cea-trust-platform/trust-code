# %% [markdown]
# # Canal_WC_VDF

# %%
from trustutils.jupyter import run
run.introduction('Elie Saikali')
# Out:
# ## Introduction
#  Validation made by : Elie Saikali
#  Report generated 26/01/2022

# %% [markdown]
# ### Description
# We run a WC problem in a channel of 21x100x21  cells (44100 cells). Two test cases are considered: case 1 with an iterative pressure solver (GCP), while case 2 with a direct solver (Cholesky).  We test the scaling by running 10 iterations on 1,2,4,8,16, 32 and 64 procs. Similar cases (case 3 and case 4) are carried out with a channel of 42x25x42 cells (44100 cells).

# %%
run.TRUST_parameters()
# Out:
# ### TRUST parameters
#  * Version TRUST: 1.8.4
#  * Binary used: /volatile/catA/ll258196/trust-code/exec/TRUST_mpi_opt (built on TRUST /volatile/catA/ll258196/trust-code/Validation/Rapports_automatiques/jupyter/Perf/Canal_WC_VDF/build)

# %%
run.addCase("SEQ_C1" ,"Cas.data",1)
run.addCase("PAR_2_C1" ,"PAR_Cas.data",2)
run.addCase("PAR_4_C1" ,"PAR_Cas.data",4)
run.addCase("PAR_8_C1" ,"PAR_Cas.data",8)
run.addCase("PAR_16_C1" ,"PAR_Cas.data",16)
run.addCase("PAR_32_C1" ,"PAR_Cas.data",32)

run.addCase("SEQ_C2" ,"Cas2.data",1)
run.addCase("PAR_2_C2" ,"PAR_Cas2.data",2)
run.addCase("PAR_4_C2" ,"PAR_Cas2.data",4)
run.addCase("PAR_8_C2" ,"PAR_Cas2.data",8)
run.addCase("PAR_16_C2" ,"PAR_Cas2.data",16)
run.addCase("PAR_32_C2" ,"PAR_Cas2.data",32)

run.addCase("SEQ_C3" ,"Cas.data",1)
run.addCase("PAR_2_C3" ,"PAR_Cas.data",2)
run.addCase("PAR_4_C3" ,"PAR_Cas.data",4)
run.addCase("PAR_8_C3" ,"PAR_Cas.data",8)
run.addCase("PAR_16_C3" ,"PAR_Cas.data",16)
run.addCase("PAR_32_C3" ,"PAR_Cas.data",32)

run.addCase("SEQ_C4" ,"Cas2.data",1)
run.addCase("PAR_2_C4" ,"PAR_Cas2.data",2)
run.addCase("PAR_4_C4" ,"PAR_Cas2.data",4)
run.addCase("PAR_8_C4" ,"PAR_Cas2.data",8)
run.addCase("PAR_16_C4" ,"PAR_Cas2.data",16)
run.addCase("PAR_32_C4" ,"PAR_Cas2.data",32)

run.printCases()
run.runCases()
# Out:
# ### Test cases
# * SEQ_C1/Cas.data :
# * PAR_2_C1/PAR_Cas.data :
# * PAR_4_C1/PAR_Cas.data :
# * PAR_8_C1/PAR_Cas.data :
# * PAR_16_C1/PAR_Cas.data :
# * PAR_32_C1/PAR_Cas.data :
# * SEQ_C2/Cas2.data :
# * PAR_2_C2/PAR_Cas2.data :
# * PAR_4_C2/PAR_Cas2.data :
# * PAR_8_C2/PAR_Cas2.data :
# * PAR_16_C2/PAR_Cas2.data :
# * PAR_32_C2/PAR_Cas2.data :
# * SEQ_C3/Cas.data :
# * PAR_2_C3/PAR_Cas.data :
# * PAR_4_C3/PAR_Cas.data :
# * PAR_8_C3/PAR_Cas.data :
# * PAR_16_C3/PAR_Cas.data :
# * PAR_32_C3/PAR_Cas.data :
# * SEQ_C4/Cas2.data :
# * PAR_2_C4/PAR_Cas2.data :
# * PAR_4_C4/PAR_Cas2.data :
# * PAR_8_C4/PAR_Cas2.data :
# * PAR_16_C4/PAR_Cas2.data :
# * PAR_32_C4/PAR_Cas2.data :
# Running ...
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
# ./pre_run
#   => A total of 24 cases were (successfully) run in 177.3s.

# %% [markdown]
# ### Case 1 : pressure with PetSC GCP

# %%
from trustutils import plot

a = plot.Graph("pressure with PetSC GCP")

x,y = plot.loadText("PAR_32_C1/Cas_all.perf.txt")
a.add(x,y,label="perf",marker='-x')

a.label("Time [s]","PROC NUMBER")

# %% [markdown]
# ### Case 2 : pressure with PetSC Cholesky

# %%
from trustutils import plot

a = plot.Graph("pressure with PetSC Cholesky")

x,y = plot.loadText("PAR_32_C2/Cas_all2.perf.txt")
a.add(x,y,label="perf",marker='-x')

a.label("Time [s]","PROC NUMBER")

# %% [markdown]
# ### Case 3 : pressure with PetSC GCP

# %%
from trustutils import plot

a = plot.Graph("pressure with PetSC GCP")

x,y = plot.loadText("PAR_32_C3/Cas_all.perf.txt")
a.add(x,y,label="perf",marker='-x')

a.label("Time [s]","PROC NUMBER")

# %% [markdown]
# ### Case 4 : pressure with PetSC Cholesky

# %%
from trustutils import plot

a = plot.Graph("pressure with PetSC Cholesky")

x,y = plot.loadText("PAR_32_C4/Cas_all2.perf.txt")
a.add(x,y,label="perf",marker='-x')

a.label("Time [s]","PROC NUMBER")

# %% [markdown]
# ## Conclusions
#
# Case 1 : good scaling up to 8 procs (5625 cell / proc, acceleration of about 75 %). Above that MPI communications become significant! Case 2 : good scaling up to 16 procs (2812 cell / proc, acceleration of about 57 %). 16 procs for case 3 and case 4.

# %% [markdown]
# ## Computer performance

# %%
run.tablePerf()
# Out:
#                         host system  Total CPU Time CPU time/step  \
# SEQ_C1/Cas          is244522  Linux         5.48320      0.515314
# PAR_2_C1/PAR_Cas    is244522  Linux         3.81817      0.357352
# PAR_4_C1/PAR_Cas    is244522  Linux         2.99477        0.2802
# PAR_8_C1/PAR_Cas    is244522  Linux         3.80707      0.353218
# PAR_16_C1/PAR_Cas   is244522  Linux        15.83360       1.44266
# PAR_32_C1/PAR_Cas   is244522  Linux        19.49130       1.72615
# SEQ_C2/Cas2         is244522  Linux         2.22917     0.0941023
# PAR_2_C2/PAR_Cas2   is244522  Linux         1.49752     0.0609237
# PAR_4_C2/PAR_Cas2   is244522  Linux         1.31104     0.0593094
# PAR_8_C2/PAR_Cas2   is244522  Linux         1.90536     0.0856146
# PAR_16_C2/PAR_Cas2  is244522  Linux         7.59914      0.416488
# PAR_32_C2/PAR_Cas2  is244522  Linux        13.36290      0.637185
# SEQ_C3/Cas          is244522  Linux         6.04297      0.561995
# PAR_2_C3/PAR_Cas    is244522  Linux         4.22494      0.390673
# PAR_4_C3/PAR_Cas    is244522  Linux         2.96060      0.274424
# PAR_8_C3/PAR_Cas    is244522  Linux         3.43171      0.314732
# PAR_16_C3/PAR_Cas   is244522  Linux         7.17621      0.635404
# PAR_32_C3/PAR_Cas   is244522  Linux        21.47570       1.89105
# SEQ_C4/Cas2         is244522  Linux         2.56259     0.0901036
# PAR_2_C4/PAR_Cas2   is244522  Linux         1.92876     0.0658195
# PAR_4_C4/PAR_Cas2   is244522  Linux         1.33707     0.0594578
# PAR_8_C4/PAR_Cas2   is244522  Linux         1.98227     0.0663312
# PAR_16_C4/PAR_Cas2  is244522  Linux         4.82684      0.147982
# PAR_32_C4/PAR_Cas2  is244522  Linux        11.31340      0.469853
# Total                                     148.59630
#
#                    number of cells
# SEQ_C1/Cas                   44100
# PAR_2_C1/PAR_Cas       44100-44100
# PAR_4_C1/PAR_Cas       44100-44100
# PAR_8_C1/PAR_Cas       44100-44100
# PAR_16_C1/PAR_Cas      44100-44100
# PAR_32_C1/PAR_Cas      44100-44100
# SEQ_C2/Cas2                  44100
# PAR_2_C2/PAR_Cas2      44100-44100
# PAR_4_C2/PAR_Cas2      44100-44100
# PAR_8_C2/PAR_Cas2      44100-44100
# PAR_16_C2/PAR_Cas2     44100-44100
# PAR_32_C2/PAR_Cas2     44100-44100
# SEQ_C3/Cas                   44100
# PAR_2_C3/PAR_Cas       44100-44100
# PAR_4_C3/PAR_Cas       44100-44100
# PAR_8_C3/PAR_Cas       44100-44100
# PAR_16_C3/PAR_Cas      44100-44100
# PAR_32_C3/PAR_Cas      44100-44100
# SEQ_C4/Cas2                  44100
# PAR_2_C4/PAR_Cas2      44100-44100
# PAR_4_C4/PAR_Cas2      44100-44100
# PAR_8_C4/PAR_Cas2      44100-44100
# PAR_16_C4/PAR_Cas2     44100-44100
# PAR_32_C4/PAR_Cas2     44100-44100
# Total

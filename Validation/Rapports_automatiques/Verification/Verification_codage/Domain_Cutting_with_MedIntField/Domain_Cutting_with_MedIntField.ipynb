# %% [markdown]
# # Read partition from MED file

# %%
from trustutils import run

run.introduction("Luc Lecointre","28/03/2022") 
run.description("Read partition from MED file")
run.TRUST_parameters("1.9.0")

# %% [markdown]
# ## Generation of mesh with Thread field

# %%
run.addCase(".","test.data",4) 
run.printCases()
run.runCases()

# %% [markdown]
# ## Partitionnement

# %%
from trustutils import visit

fig=visit.Show("test.lata","Subset","blocks(dom)",nX=1,nY=1,mesh="dom",title="",time=-1)
fig.rotation3D([45,45,45])
fig.plot()

# %% [markdown]
# ## Pressure

# %%
fig=visit.Show("test.lata","Pseudocolor","PRESSION_ELEM_dom",nX=1,nY=1,mesh="dom",title="",time=-1)
fig.rotation3D([45,45,45])
fig.plot()

# %% [markdown]
# ## Computer performance

# %%
run.tablePerf()
